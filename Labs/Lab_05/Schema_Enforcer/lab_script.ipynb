# %%
import csv
import json
import pandas as pd

data = [
        ['student_id', 'major', 'GPA', 'is_cs_major', 'credits_taken'],
        [1, 'english', 3.75, 'No', '14'],
        [2, 'biology', 3, 'No', '30.5'],
        [3, 'computer science', 3.88, 'Yes', '24'],
        [4, 'finance', 4, 'No', '22'],
        [5, 'civil engineering', 2.67, 'No', '18.5']
]

with open('raw_survey_data.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerows(data)
dict_data = [
  {
    "course_id": "DS2002",
    "section": "001",
    "title": "Data Science Systems",
    "level": 2000,
    "instructors": [
      {"name": "Austin Rivera", "role": "Primary"},
      {"name": "Heywood Williams-Tracy", "role": "TA"}
    ]
  },
  {
    "course_id": "MAE3310",
    "title": "Aerospace Structures",
    "level": 3000,
    "instructors": [
      {"name": "Mike Momot", "role": "Primary"}
    ]
  },{
    "course_id": "MAE3420",
    "title": "Computational Methods in MAE",
    "level": 3000,
    "instructors": [
      {"name": "Chen Cui", "role": "Primary"}
    ]
  },{
    "course_id": "MAE3210",
    "title": "Fluid Mechanics",
    "level": 3000,
    "instructors": [
      {"name": "Daniel Quinn", "role": "Primary"}
    ]
  }
]

with open('raw_course_catalog.json', 'w') as file:
        json.dump(dict_data, file)

df = pd.read_csv('raw_survey_data.csv')
df['is_cs_major'] = df['is_cs_major'].replace({'Yes': True, 'No': False})
df['GPA'] = df['GPA'].astype(float)
df['credits_taken'] = df['credits_taken'].astype(float)
df.to_csv('clean_survey_data.csv', index = False)

with open('raw_course_catalog.json', 'r') as file:
        json_data = json.load(file)
json_data = pd.json_normalize(json_data, record_path=['instructors'], meta=['course_id', 'title', 'level'])
json_data.to_csv('clean_course_catalog.csv', index = False)
# Out:
# /tmp/ipykernel_2187/3890296892.py:56: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['is_cs_major'] = df['is_cs_major'].replace({'Yes': True, 'No': False})
